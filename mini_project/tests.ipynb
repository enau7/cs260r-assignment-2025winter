# %%
# !python eval.py --agent-name="agent_random" --num-processes=1 --num-episodes-per-processes=1
# Out:
# ...
# EVALUATING AGENT agent_random (CREATOR: Zhenghao Peng, UID: 0000000000)
# ...
# Start evaluation!
# ...
# THE PERFORMANCE OF agent_random:
#
# crash_sidewalk_rate: 0.0
# crash_vehicle_rate: 0.0
# episode_cost: 0.0
# episode_length: 1000.0
# episode_reward: 8.523252608432813
# max_step_rate: 1.0
# out_of_road_rate: 0.0
# route_completion: 0.027126115770883575
# success_rate: 0.0
#
# ...
# [INFO] Environment: SafeMetaDriveEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 1000
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 1000, Num Scenarios : 50
#
# ...
#   0%|          | 0/1 [00:02<?, ?it/s][INFO] Episode ended! Scenario Index: 1031 Reason: max step
#
# ...
# 100%|██████████| 1/1 [00:02<00:00,  2.29s/it]

# %%
# !python eval.py --agent-name="agent_sb3" --num-processes=1 --num-episodes-per-processes=1
# Out:
# ...
# EVALUATING AGENT agent_sb3 (CREATOR: Zhenghao Peng, UID: 000000000)
# ...
# Start evaluation!
# ...
# THE PERFORMANCE OF agent_sb3:
#
# crash_sidewalk_rate: 0.0
# crash_vehicle_rate: 0.0
# episode_cost: 1.0
# episode_length: 339.0
# episode_reward: 85.04925868287683
# max_step_rate: 0.0
# out_of_road_rate: 1.0
# route_completion: 0.3420083414279597
# success_rate: 0.0
#
# ...
# [INFO] Environment: SafeMetaDriveEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 1000
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 1000, Num Scenarios : 50
#
# ...
#   0%|          | 0/1 [00:00<?, ?it/s][INFO] Episode ended! Scenario Index: 1014 Reason: out_of_road.
#
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]

# %%
# !python eval.py --agent-name="agent_706538005"
# Out:
# [INFO] Environment: SafeMetaDriveEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 1000
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "c:\Users\Colton\anaconda3\envs\cs260r\Lib\multiprocessing\spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Colton\anaconda3\envs\cs260r\Lib\multiprocessing\spawn.py", line 131, in _main
#     prepare(preparation_data)
#   File "c:\Users\Colton\anaconda3\envs\cs260r\Lib\multiprocessing\spawn.py", line 246, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "c:\Users\Colton\anaconda3\envs\cs260r\Lib\multiprocessing\spawn.py", line 297, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
# ...
